# %%
import pandas as pd

# %%
data = pd.read_csv("/projects/net_contrast_classification/contrast_phase/data/cleaned_data_matchkey_added.csv")

# %%
print(data.is_liver_imaged.value_counts(dropna=False), "\n\n",
      data.contrast.value_counts(dropna=False), "\n\n",
      data.phase_timing.value_counts(dropna=False))
# Out:
# is_liver_imaged
# Yes          7831
# Partially     369
# 0             189
# NaN           157
# Name: count, dtype: int64
#
#  contrast
# Portal          3690
# Arterial        2485
# Non-contrast    2114
# 0                257
# Name: count, dtype: int64
#
#  phase_timing
# Just Right      5093
# Non-contrast    2114
# Too Early        916
# 0.0              253
# Too Late         170
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8546 entries, 0 to 8545
# Data columns (total 49 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   NiiFile                             8546 non-null   str
#  1   SegNiiFile                          8546 non-null   str
#  2   Original File                       8546 non-null   str
#  3   Destination Folder                  8546 non-null   str
#  4   New File                            8546 non-null   str
#  5   SubjectKeyRadiology                 8546 non-null   str
#  6   ExamDate                            8546 non-null   str
#  7   file                                8546 non-null   str
#  8   is_liver_imaged                     8389 non-null   str
#  9   contrast                            8546 non-null   str
#  10  phase_timing                        8546 non-null   str
#  11  is_lesionfree                       8546 non-null   str
# ...

# %%
kalina_check = data[(data.contrast == "0") 
                                                 | (data.is_liver_imaged == "0")
                                                 | (data.phase_timing == 0.0)
              ]

kalina_check[["MatchKey", "is_liver_imaged", "contrast", "phase_timing", "ProtocolName", "BodyPartExamined"]].to_csv("/projects/net_contrast_classification/contrast_phase/data/kalina_check_zeros.csv", index=False)

# %%
# radiomics_contrast_misclass = pd.read_csv("/projects/net_contrast_classification/contrast_phase/data/radiomics_contrast_misclass.csv")
# radiomics_contrast_misclass[['image', 'contrast', 'pred_contrast']].to_csv("/projects/net_contrast_classification/contrast_phase/data/kalina_check_radiomics_contrast_misclass.csv", index=False)
