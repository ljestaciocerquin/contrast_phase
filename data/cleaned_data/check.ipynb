# %%
import pandas as pd

data = pd.read_csv("/projects/net_contrast_classification/contrast_phase/data/cleaned_data/cleaned_data.csv")
data_prior = pd.read_csv("/projects/net_contrast_classification/contrast_phase/data/cleaned_data/cleaned_data_server_flag.csv")

# %%
print(len(data[data.SubjectKeyRadiology.notna()]), len(data[data.exist_on_server.notna()]))

print(len(data_prior[data_prior.SubjectKeyRadiology.notna()]), len(data_prior[data_prior.exist_on_server.notna()]))
# Out:
# 8546 5441
# 8546 5441

# %%
len(data_prior[data_prior.file.isna()])
# Out:
# 0

# %%
print(
    "Duplicate MatchKeys in data_with_flag:",
    data_prior["MatchKey"].duplicated().sum()
)
# Out:
# Duplicate MatchKeys in data_with_flag: 0
